# %%
# !pip install reportlab
from reportlab.pdfgen import canvas
from reportlab.lib.pagesizes import letter

def create_sample_pdf(filename="example.pdf"):
    text = """Artificial Intelligence (AI) refers to the simulation of human intelligence in machines that are programmed to think and learn like humans. AI technologies include machine learning, natural language processing, robotics, and computer vision. These technologies have vast applications in healthcare, finance, automotive industries, and more.

Machine learning, a subset of AI, enables computers to learn from data without being explicitly programmed. It is widely used in predictive analytics, recommendation systems, and autonomous vehicles.

Natural Language Processing (NLP) allows computers to understand and generate human language. This technology powers chatbots, virtual assistants, and language translation services.

The future of AI promises smarter machines that can assist in complex decision-making, automate routine tasks, and improve quality of life.
"""
    c = canvas.Canvas(filename, pagesize=letter)
    width, height = letter
    margin = 40
    y = height - margin
    line_height = 14

    for line in text.split('\n'):
        c.drawString(margin, y, line)
        y -= line_height

    c.save()
    print(f"PDF saved as {filename}")

create_sample_pdf()
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 26.6 MB/s eta 0:00:00
# ...
# PDF saved as example.pdf

# %%
pip install llama-index pdfplumber
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.2/60.2 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 45.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 33.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.3/267.3 kB 21.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 33.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.2/304.2 kB 16.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.3/129.3 kB 12.0 MB/s eta 0:00:00
# ...

# %%
# !pip install llama-index langchain transformers sentence-transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 69.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 72.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 63.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
pip install --upgrade llama-index langchain transformers sentence-transformers

# %%
# !pip uninstall -y llama-index gpt-index
# Out:
# Found existing installation: llama-index 0.12.41
# Uninstalling llama-index-0.12.41:
#   Successfully uninstalled llama-index-0.12.41
# WARNING: Skipping gpt-index as it is not installed.

# %%
# !pip install --upgrade llama-index
# Out:
# ...
#   Using cached llama_index-0.12.41-py3-none-any.whl.metadata (12 kB)
# ...
# Using cached llama_index-0.12.41-py3-none-any.whl (7.1 kB)
# ...

# %%
# First, uninstall any existing llama-index or gpt-index installations
# !pip uninstall -y llama-index gpt-index

# Then, reinstall llama-index
# !pip install llama-index

# Now, import and check the version
import llama_index
print(llama_index.__version__)
# Out:
# Found existing installation: llama-index 0.12.41
# Uninstalling llama-index-0.12.41:
#   Successfully uninstalled llama-index-0.12.41
# WARNING: Skipping gpt-index as it is not installed.
# ...
#   Using cached llama_index-0.12.41-py3-none-any.whl.metadata (12 kB)
# ...
# Using cached llama_index-0.12.41-py3-none-any.whl (7.1 kB)
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-1ba6e2f3f96b> in <cell line: 0>()
#       7 # Now, import and check the version
#       8 import llama_index
# ----> 9 print(llama_index.__version__)
#
# AttributeError: module 'llama_index' has no attribute '__version__'

# %%
# First, uninstall any existing llama-index or gpt-index installations
# !pip uninstall -y llama-index gpt-index

# Then, reinstall llama-index with necessary dependencies
# !pip install llama-index --upgrade --no-cache-dir

# Now, import and check the version
import llama_index
print(f"LlamaIndex version: {llama_index.__version__}")

# Additionally, check the location of the imported module
print(f"LlamaIndex module path: {llama_index.__file__}")
# Out:
# Found existing installation: llama-index 0.12.41
# Uninstalling llama-index-0.12.41:
#   Successfully uninstalled llama-index-0.12.41
# WARNING: Skipping gpt-index as it is not installed.
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-55a1bc47d6ad> in <cell line: 0>()
#       7 # Now, import and check the version
#       8 import llama_index
# ----> 9 print(f"LlamaIndex version: {llama_index.__version__}")
#      10
#      11 # Additionally, check the location of the imported module
#
# AttributeError: module 'llama_index' has no attribute '__version__'

# %%
from llama_index import (
    GPTVectorStoreIndex,
    LLMPredictor,
    PromptHelper,
)
from llama_index.readers.file.base import SimpleDirectoryReader  # For loading files

from langchain.llms import HuggingFacePipeline
from transformers import pipeline

# Load documents from PDF
documents = SimpleDirectoryReader(input_files=['example.pdf']).load_data()

# Setup HuggingFace text-generation pipeline
hf_pipeline = pipeline(
    "text-generation",
    model="mistralai/Mistral-7B-Instruct-v0.1",
    max_length=512,
    temperature=0.7,
    top_p=0.95,
)

hf_llm = HuggingFacePipeline(pipeline=hf_pipeline)
llm_predictor = LLMPredictor(llm=hf_llm)
prompt_helper = PromptHelper(max_input_size=4096, num_output=512, max_chunk_overlap=20)

# Create index
index = GPTVectorStoreIndex(
    documents,
    llm_predictor=llm_predictor,
    prompt_helper=prompt_helper
)

query_engine = index.as_query_engine()
response = query_engine.query("Summarize the document")

print(response)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-19-6d2a57abb605> in <cell line: 0>()
# ----> 1 from llama_index import (
#       2     GPTVectorStoreIndex,
#       3     LLMPredictor,
#       4     PromptHelper,
#       5 )
#
# ImportError: cannot import name 'GPTVectorStoreIndex' from 'llama_index' (unknown location)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
