# %%
# 📦 Step 1: Install required packages
# !pip install -q langchain langchain_groq groq newspaper3k googlesearch-python

# 📚 Step 2: Import libraries
import os
import nltk
from googlesearch import search
from newspaper import Article
from langchain_groq import ChatGroq
from langchain.prompts import PromptTemplate
from urllib.parse import urlparse

# 🛠️ Step 3: Download tokenizer used by newspaper3k
nltk.download('punkt')

# 🔐 Step 4: Set Groq API key (⚠️ Paste your actual key here)
GROQ_API_KEY = "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"
os.environ["GROQ_API_KEY"] = GROQ_API_KEY

# 🤖 Step 5: Initialize Groq LLM
llm = ChatGroq(
    temperature=0.2,
    groq_api_key=GROQ_API_KEY,
    model_name="llama3-70b-8192"
)

# 💬 Step 6: Input your research topic
topic = input("📘 Enter your research topic:\n> ")

# 🔎 Step 7: Perform Google search (filter valid URLs)
print("🔍 Searching Google...")
search_results = [url for url in search(topic, num_results=5) if url.startswith("http")]
print("\n🔗 Top results found:\n")
for link in search_results:
    print(link)

# 🛡️ Step 8: Function to detect unsupported domains
def is_supported_url(url):
    domain = urlparse(url).netloc
    unsupported_domains = [
        "apsnet.org", "sciencedirect.com", "ieee.org", "dl.acm.org",
        "springerlink.com", "link.springer.com", "mdpi.com", "tandfonline.com"
    ]
    return all(bad not in domain for bad in unsupported_domains)

# 🧠 Step 9: Summarize supported articles
summaries = []
for url in search_results:
    print(f"\n📰 Processing: {url}")

    if not is_supported_url(url):
        summaries.append(f"⚠️ Skipped unsupported URL (likely protected or dynamic): {url}\n")
        print("⚠️ Skipped unsupported URL.")
        continue

    try:
        article = Article(url)
        article.download()
        article.parse()
        content = article.text[:4000]  # Limit content to avoid token overload

        prompt = PromptTemplate.from_template(
            "Summarize the following article in a clear, academic tone:\n\n{content}\n\nSummary:"
        )
        summary = llm.invoke(prompt.format(content=content)).content
        summaries.append(f"🔗 URL: {url}\n📝 Summary:\n{summary}\n")
    except Exception as e:
        summaries.append(f"⚠️ Failed to process {url}:\n{str(e)}\n")

# 📢 Step 10: Output all summaries
print("\n✅ Final Summaries:\n")
for s in summaries:
    print(s)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 📘 Enter your research topic:
# > PLANT DISEASE DETECTION
# 🔍 Searching Google...
#
# 🔗 Top results found:
#
# https://journalofbigdata.springeropen.com/articles/10.1186/s40537-023-00863-9
# https://www.nature.com/articles/s41598-023-34549-2
# https://www.frontiersin.org/journals/plant-science/articles/10.3389/fpls.2024.1356260/full
# https://apsjournals.apsnet.org/doi/10.1094/PDIS-03-15-0340-FE
# https://plantmethods.biomedcentral.com/articles/10.1186/s13007-021-00722-9
#
# 📰 Processing: https://journalofbigdata.springeropen.com/articles/10.1186/s40537-023-00863-9
#
# 📰 Processing: https://www.nature.com/articles/s41598-023-34549-2
#
# 📰 Processing: https://www.frontiersin.org/journals/plant-science/articles/10.3389/fpls.2024.1356260/full
#
# 📰 Processing: https://apsjournals.apsnet.org/doi/10.1094/PDIS-03-15-0340-FE
# ⚠️ Skipped unsupported URL.
#
# 📰 Processing: https://plantmethods.biomedcentral.com/articles/10.1186/s13007-021-00722-9
#
# ✅ Final Summaries:
#
# 🔗 URL: https://journalofbigdata.springeropen.com/articles/10.1186/s40537-023-00863-9
# 📝 Summary:
# This study provides a comprehensive review of recent literature on plant leaf disease detection and classification using various machine learning (ML) and deep learning (DL) techniques. The reviewed studies employed different approaches, such as convolutional neural networks (CNNs), transfer learning, and generative adversarial networks, to detect and classify plant leaf diseases with high accuracy.
#
# The reviewed studies demonstrated the effectiveness of DL-based approaches in detecting and classifying plant leaf diseases, with accuracy rates ranging from 97% to 99.7%. For instance, a study using YoloV5 achieved 98.75% accuracy in detecting and identifying insects in soybean crops. Another study using CNN achieved 98.29% accuracy in classifying plant leaf diseases from the PlantVillage dataset.
#
# The reviewed studies also highlighted the importance of using large datasets, such as the PlantVillage dataset, and collecting images from various devices to improve the accuracy of disease detection and classification. Additionally, the studies demonstrated the effectiveness of using techniques such as Otsu's global thresholding to remove image background noise and using fully connected CNNs to detect rice diseases.
#
# The study also highlighted the use of CNNs in identifying and classifying tomato leaf diseases, achieving an accuracy of greater than 99% in both training and test datasets. Furthermore, the use of generative adversarial networks was shown to be effective in avoiding overfitting and improving the accuracy of disease detection and classification.
#
# Overall, the reviewed studies demonstrate the potential of DL-based approaches in detecting and classifying plant leaf diseases with high accuracy, and highlight the importance of using large datasets and effective techniques to improve the accuracy of disease detection and classification.
#
# 🔗 URL: https://www.nature.com/articles/s41598-023-34549-2
# 📝 Summary:
# The article presents a three-step detection model for plant diseases using leaf images of bell pepper, potato, and tomato. The model consists of crop classification, disease detection, and disease classification. In the first step, a crop classification model was developed using healthy and diseased leaf images of the three crops. The model was trained and validated using five pre-trained convolutional neural network (CNN) models, and the EfficientNet architecture showed the highest accuracy of 99.33%. The model was then used to detect diseases in individual crops in the second step. Three individual disease detection models were developed for bell pepper, potato, and tomato, and the GoogLeNet, VGG19, and ResNet50 models showed the highest accuracy for each crop, respectively. The models achieved high accuracy, precision, recall, and F1-score, ranging from 99.75% to 100.00%. The study demonstrates the potential of using deep learning algorithms for crop and disease detection using leaf images.
#
# 🔗 URL: https://www.frontiersin.org/journals/plant-science/articles/10.3389/fpls.2024.1356260/full
# 📝 Summary:
# This review article highlights the significance of rapid and accurate plant disease detection in enhancing agricultural yield and reducing economic losses. Traditional methods of disease detection, which rely on visual inspection and expertise, are time-consuming and limited. The article proposes the use of artificial intelligence (AI) and Internet of Things (IoT) sensors for automated leaf disease detection. The review focuses on four crop diseases: tomato, chilli, potato, and cucumber, and discusses the most prevalent diseases and infections in these crops, along with their symptoms.
#
# The article outlines a step-by-step approach to predict plant diseases using AI, including image acquisition, preprocessing, segmentation, feature selection, and classification. It also discusses machine learning (ML) and deep learning (DL) detection models and provides a comprehensive examination of existing ML and DL-based studies on disease detection in the four crops, including the datasets used to evaluate these studies.
#
# The article identifies various application problems and discusses future research prospects, including the integration of AI with IoT platforms like smart drones for field-based disease detection. The review aims to provide a comprehensive survey of different plant disease detection strategies and the limitations of present systems, which will help practitioners in the field.
#
# Overall, the article emphasizes the need for advanced and comprehensive research to address the challenges in modern agricultural settings, and highlights the potential of AI and IoT-based approaches in improving plant disease detection and reducing crop losses.
#
# ⚠️ Skipped unsupported URL (likely protected or dynamic): https://apsjournals.apsnet.org/doi/10.1094/PDIS-03-15-0340-FE
#
# 🔗 URL: https://plantmethods.biomedcentral.com/articles/10.1186/s13007-021-00722-9
# 📝 Summary:
# This article provides an overview of deep learning-based methods for detecting diseases and pests in plants. The approaches can be categorized into three types of networks: classification, detection, and segmentation networks. The classification network is the most commonly used method, which can be further subdivided into three subcategories: using the network as a feature extractor, using the network for classification directly, and using the network for lesion location.
#
# The classification network employs convolutional neural networks (CNNs) to analyze images of plant diseases and pests. The CNNs are designed to extract features from images, which are then classified using a softmax structure. Various CNN architectures have been used, such as AlexNet, GoogleLeNet, and ResNet, as well as custom-designed networks.
#
# The first subcategory, using the network as a feature extractor, involves extracting features from images using a pre-trained CNN, and then inputting these features into a traditional machine learning classifier, such as support vector machines (SVM). This approach has been shown to be effective in classifying plant diseases and pests.
#
# The second subcategory, using the network for classification directly, involves using the CNN to classify images directly. This approach can be further divided into three sub-subcategories: original image classification, classification after locating the region of interest (ROI), and multi-category classification.
#
# The article highlights the effectiveness of deep learning-based methods in detecting plant diseases and pests, and provides a comprehensive overview of the various approaches and their applications in the field of agriculture.
